# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# Add the src directory to the Python path if needed
src_path = os.path.abspath(os.path.join(os.getcwd(), '../src'))
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# Import NeuroWorkflow components
from neuroworkflow import WorkflowBuilder
from neuroworkflow.nodes.network import TVBConnectivitySetUpNode, TVBEpileptorNode, TVBIntegratorNode, TVBVisualizationNode
from neuroworkflow.nodes.stimulus import TVBMonitorNode
from neuroworkflow.nodes.simulation import TVBSimulatorNode
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: Mar  4 2025 17:27:39
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
# upload and setup connectivity in TVB
load_sc = TVBConnectivitySetUpNode("TVBConnectivity")
# Configure the node
load_sc.configure(
    connectivity_file='connectivity_76.zip',  
)
# Print node information
print(load_sc)
# Out:
# Node: TVBConnectivity (network_builder)
# Description: Initialise the Connectivity. TVB structural connectome is read from a zip file.
# Parameters:
#   connectivity_file: connectivity_76.zip
# Output Ports:
#   tvb_connectivity (object, not connected): Configured connectivity matrix object in TVB
# Process Steps:
#   sc_initialization: Initialize the connectivity
#     Outputs: tvb_connectivity
#   sc_visualization: Visualization of connectivity matrix
#     Inputs: tvb_connectivity
#     Outputs: visualization completed

# %%
model = TVBEpileptorNode("TVBEpileptor")
# Configure the node
model.configure(
)
# Print node information
print(load_sc)
# Out:
# Node: TVBConnectivity (network_builder)
# Description: Initialise the Connectivity. TVB structural connectome is read from a zip file.
# Parameters:
#   connectivity_file: connectivity_76.zip
# Output Ports:
#   tvb_connectivity (object, not connected): Configured connectivity matrix object in TVB
# Process Steps:
#   sc_initialization: Initialize the connectivity
#     Outputs: tvb_connectivity
#   sc_visualization: Visualization of connectivity matrix
#     Inputs: tvb_connectivity
#     Outputs: visualization completed

# %%
integrator = TVBIntegratorNode("TVBIntegrator")
# Configure the node
integrator.configure(
)
# Print node information
print(integrator)
# Out:
# Node: TVBIntegrator (network_builder)
# Description: Definition of the integration scheme
# Parameters:
#   integrator: HeunStochastic
#   dt: 0.1
#   nsigma: [0.00025, 0.001]
# Output Ports:
#   tvb_integrator (object, not connected): Configured integration scheme in TVB
# Process Steps:
#   int_initialization: Initialize the integration scheme
#     Outputs: tvb_integrator

# %%
monitor = TVBMonitorNode("TVBMonitor")
# Configure the node
monitor.configure(
)
# Print node information
print(monitor)
# Out:
# Node: TVBMonitor (stimulus_or_monitor)
# Description: Definition of the monitor
# Parameters:
#   monitor_type: TemporalAverage
#   temp_avg_period: 1
# Output Ports:
#   tvb_monitor (object, not connected): Configured monitor in TVB
# Process Steps:
#   mon_initialization: Initialize the monitor
#     Outputs: tvb_monitor

# %%
simulation = TVBSimulatorNode("TVBSimulator")
# Configure the node
simulation.configure(
)
# Print node information
print(simulation)
# Out:
# Node: TVBSimulator (simulation_node)
# Description: Definition and execution of the simulation
# Parameters:
#   simulation_length: 5000
# Input Ports:
#   tvb_connectivity (object, required, not connected): Configured connectivity matrix object in TVB
#   tvb_model (object, required, not connected): The local neural (hybrid version of Epileptor Model) dynamics of each brain area
#   tvb_coupling (object, required, not connected): It is a function that is used to join the local Model dynamics at distinct spatial locations over the connections described in tvb_connectivity.
#   tvb_integrator (object, required, not connected): Configured integration scheme in TVB
#   tvb_monitor (object, required, not connected): Configured monitor in TVB
# Output Ports:
#   tvb_simdata (list, not connected): simulation data series
#   tvb_simtime (list, not connected): simulation time series
# Process Steps:
#   sim_config_and_run: Initialize the simulation object and run the simulation.
#     Inputs: tvb_connectivity, tvb_model, tvb_coupling, tvb_integrator, tvb_monitor
#     Outputs: simulation_completed

# %%
plots = TVBVisualizationNode("TVBVisualization")
# Configure the node
plots.configure(
)
# Print node information
print(plots)
# Out:
# Node: TVBVisualization (simulation_node)
# Description: Visualization of the simulation results
# Parameters:
#   plot_type: LFP
# Input Ports:
#   data_series (list, required, not connected): simulation output data series
#   time_series (list, required, not connected): simulation output time series
# Output Ports:
#   visualization_completed (bool, not connected): visualization confirmation
# Process Steps:
#   plot_lfp: plottinmg lfp from data and time series
#     Inputs: data_series, time_series

# %%
# Create a workflow builder
workflow_builder = WorkflowBuilder("Resting-State in Epilepsy")

# Add nodes to the workflow
workflow_builder.add_node(load_sc)
workflow_builder.add_node(model)
workflow_builder.add_node(integrator)
workflow_builder.add_node(monitor)
workflow_builder.add_node(simulation)
workflow_builder.add_node(plots)

# Connect the nodes
workflow_builder.connect(
    "TVBConnectivity", "tvb_connectivity", 
    "TVBEpileptor", "tvb_connectivity"
)
workflow_builder.connect(
    "TVBConnectivity", "tvb_connectivity", 
    "TVBSimulator", "tvb_connectivity"
)
workflow_builder.connect(
    "TVBEpileptor", "tvb_model", 
    "TVBSimulator", "tvb_model"
)
workflow_builder.connect(
    "TVBEpileptor", "tvb_coupling", 
    "TVBSimulator", "tvb_coupling"
)
workflow_builder.connect(
    "TVBIntegrator", "tvb_integrator", 
    "TVBSimulator", "tvb_integrator"
)
workflow_builder.connect(
    "TVBMonitor", "tvb_monitor", 
    "TVBSimulator", "tvb_monitor"
)
workflow_builder.connect( 
    "TVBSimulator", "tvb_simdata",
    "TVBVisualization", "data_series",
)

# Build the workflow
workflow = workflow_builder.build()

# Print workflow information
print(workflow)
# Out:
# Workflow: Resting-State in Epilepsy
# Nodes:
#   TVBConnectivity
#   TVBEpileptor
#   TVBIntegrator
#   TVBMonitor
#   TVBSimulator
# Connections:
#   TVBConnectivity.tvb_connectivity -> TVBEpileptor.tvb_connectivity
#   TVBConnectivity.tvb_connectivity -> TVBSimulator.tvb_connectivity
#   TVBEpileptor.tvb_model -> TVBSimulator.tvb_model
#   TVBEpileptor.tvb_coupling -> TVBSimulator.tvb_coupling
#   TVBIntegrator.tvb_integrator -> TVBSimulator.tvb_integrator
#   TVBMonitor.tvb_monitor -> TVBSimulator.tvb_monitor

# %%
# Execute the workflow
print("Executing workflow...")
success = workflow.execute()

if success:
    print("\nWorkflow execution completed successfully!")
else:
    print("\nWorkflow execution failed!")
# Out:
# Executing workflow...
# Executing node: TVBMonitor
# Executing node: TVBIntegrator
# passed HeunStochastic
# Executing node: TVBConnectivity
# 2025-07-02 14:14:06,220 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# Executing node: TVBEpileptor
# Executing node: TVBSimulator
# simulation required 5.120 seconds.
# Warning: Expected output 'simulation_completed' not produced by process step 'sim_config_and_run' (method: sim_config_and_run)
#
# Workflow execution completed successfully!
